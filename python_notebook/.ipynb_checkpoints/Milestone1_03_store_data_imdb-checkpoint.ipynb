# %% [markdown]
# # Store data
#
# As calling API everytime may takes a while and we may hit the limit of API, we will store the data from API for now.

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = "71e259894a515060876bab2a33d6bdc9"

# %%
import imdb as ib
from imdb import IMDb
import pandas as pd
from PIL import Image
from StringIO import StringIO
import requests
import os
import time
from shutil import copyfile
import types
import numpy as np

# %%
dir_python_notebook = os.getcwd()
dir_movie_project = os.path.abspath(os.path.join(dir_python_notebook, os.pardir))
dir_data = os.path.join(dir_movie_project, 'data')

# %% [markdown]
# # IMDB

# %%
imdb = IMDb()
#get a movie by id
imdb_movie = imdb.get_movie('0325980')
#access attributes of the movie by dictionary keys
imdb.update(imdb_movie)
#available keys
imdb_info_column  =imdb_movie.keys()
imdb_info_column  = [str(c) for c in imdb_info_column]
imdb_info_column.sort()

# %%
print(len(imdb_info_column))
print(imdb_info_column)
# Out:
# 61
# ['akas', 'animation department', 'art department', 'art direction', 'aspect ratio', 'assistant director', 'camera and electrical department', 'canonical title', 'cast', 'casting department', 'casting director', 'certificates', 'cinematographer', 'color info', 'costume department', 'costume designer', 'countries', 'country codes', 'cover url', 'director', 'distributors', 'editor', 'editorial department', 'full-size cover url', 'genres', 'kind', 'language codes', 'languages', 'location management', 'long imdb canonical title', 'long imdb title', 'make up', 'miscellaneous companies', 'miscellaneous crew', 'mpaa', 'music department', 'original music', 'plot', 'plot outline', 'producer', 'production companies', 'production design', 'production manager', 'rating', 'runtimes', 'set decoration', 'smart canonical title', 'smart long imdb canonical title', 'sound crew', 'sound mix', 'special effects companies', 'special effects department', 'stunt performer', 'thanks', 'title', 'top 250 rank', 'transportation department', 'visual effects', 'votes', 'writer', 'year']

# %%
# IMDB API shows that we can retrieve information from proprty of movies object
imdb_info_column = imdb_movie.keys_alias.keys() 
imdb_info_column.sort()
print(len(imdb_info_column))
print(imdb_info_column)
# Out:
# 85
# ['actors', 'actresses', 'aka', 'also known as', 'amazon review', 'art direction by', 'casting', 'casting by', 'certificate', 'certification', 'certifications', 'cinematography', 'cinematography by', 'color', 'costume and wardrobe department', 'costume design', 'costume design by', 'country', 'cover', 'created by', 'crew members', 'crewmembers', 'directed by', 'distribution', 'distribution companies', 'distribution company', 'distributor', 'editing', 'episodes cast', 'episodes number', 'faq', 'film editing', 'film editing by', 'frequently asked questions', 'full-size cover', 'genre', 'guest', 'guest appearances', 'lang', 'language', 'make-up', 'makeup', 'makeup department', 'merchandise', 'merchandising', 'misc companies', 'misc company', 'misc crew', 'miscellaneous', 'miscellaneous company', 'miscellaneous links', 'miscellaneouscrew', 'music', 'non-original music by', 'notable tv guest appearances', 'original music by', 'other companies', 'other company', 'other crew', 'parental guide', 'photographs', 'plot summaries', 'plot summary', 'produced by', 'production company', 'production countries', 'production country', 'production management', 'runtime', 'sales', 'seasons', 'second unit director', 'second unit director or assistant director', 'set decoration by', 'sound department', 'soundclips', 'special effects by', 'special effects company', 'stunts', 'tv guests', 'tv schedule', 'user rating', 'videoclips', 'visual effects by', 'writing credits']

# %%
for c in imdb_info_column:
    if imdb_movie.get(c) is None:
        print(c)
    #else:
    #    print (imdb_movie.get(c))
# Out:
# amazon review
# created by
# episodes cast
# episodes number
# faq
# frequently asked questions
# full-size cover
# guest
# guest appearances
# merchandise
# merchandising
# miscellaneous
# miscellaneous links
# non-original music by
# notable tv guest appearances
# parental guide
# photographs
# sales
# seasons
# soundclips
# special effects by
# tv guests
# tv schedule
# videoclips

# %%
# IMDB API shows that we can retrieve information from proprty of movies object
imdb_info_column2 = imdb_movie.keys_alias.values() 
imdb_info_column2 = list(set(imdb_info_column2))
imdb_info_column2.sort()
print(len(imdb_info_column2))
print(imdb_info_column2)
# Out:
# 49
# ['airing', 'akas', 'amazon reviews', 'art direction', 'assistant director', 'cast', 'casting director', 'certificates', 'cinematographer', 'color info', 'costume department', 'costume designer', 'countries', 'cover url', 'creator', 'director', 'distributors', 'editor', 'faqs', 'full-size cover url', 'genres', 'guests', 'languages', 'make up', 'merchandising links', 'misc links', 'miscellaneous companies', 'miscellaneous crew', 'non-original music', 'number of episodes', 'number of seasons', 'original music', 'parents guide', 'photo sites', 'plot', 'producer', 'production companies', 'production manager', 'rating', 'runtimes', 'set decoration', 'sound clips', 'sound crew', 'special effects', 'special effects companies', 'stunt performer', 'video clips', 'visual effects', 'writer']

# %%
for c in imdb_info_column2:
    print(c)
    if (imdb_movie.has_key(c)):
        print(imdb_movie[c])
    else:
        print(None)
# Out:
# airing
# None
# akas
# [u'Pirates of the Caribbean: The Curse of the Black Pearl::Australia (imdb display title), Canada (English title) (imdb display title)', u'P.O.T.C.::USA (promotional abbreviation)', u'Piratas del Caribe - La maldici\xf3n del Perla Negra::Mexico, Panama, Uruguay', u'Fluch der Karibik::Austria, Germany', u'\u039f\u03b9 \u03c0\u03b5\u03b9\u03c1\u03b1\u03c4\u03ad\u03c2 \u03c4\u03b7\u03c2 \u039a\u03b1\u03c1\u03b1\u03ca\u03b2\u03b9\u03ba\u03ae\u03c2: \u0397 \u03ba\u03b1\u03c4\u03ac\u03c1\u03b1 \u03c4\u03bf\u03c5 \u039c\u03b1\u03cd\u03c1\u03bf\u03c5 \u039c\u03b1\u03c1\u03b3\u03b1\u03c1\u03b9\u03c4\u03b1\u03c1\u03b9\u03bf\u03cd::Greece', u'\u041a\u0430\u0440\u0438\u0431\u0441\u043a\u0438 \u043f\u0438\u0440\u0430\u0442\u0438: \u041f\u0440\u043e\u043a\u043b\u044f\u0442\u0438\u0435\u0442\u043e \u043d\u0430 \u0427\u0435\u0440\u043d\u0430\u0442\u0430 \u043f\u0435\u0440\u043b\u0430::Bulgaria (Bulgarian title)', u'\u041f\u0438\u0440\u0430\u0442\u044b \u041a\u0430\u0440\u0438\u0431\u0441\u043a\u043e\u0433\u043e \u043c\u043e\u0440\u044f: \u041f\u0440\u043e\u043a\u043b\u044f\u0442\u0438\u0435 \u0427\u0451\u0440\u043d\u043e\u0439 \u0436\u0435\u043c\u0447\u0443\u0436\u0438\u043d\u044b::Russia', u'A Karib-tenger kal\xf3zai: A Fekete Gy\xf6ngy \xe1tka::Hungary (imdb display title)', u"Karayip korsanlari - Siyah inci'nin laneti::Turkey (Turkish title)", u'Karibu juras pirati: Melnas perles lasts::Latvia (imdb display title)', u'Karibu piratai: Juodojo perlo prakeiksmas::Lithuania (imdb display title)', u'Kariibi mere piraadid: Musta p\xe4rli needus::Estonia (imdb display title)', u'La maldici\xf3n del Perla Negra::Argentina', u'La maledizione della prima luna::Italy (imdb display title)', u'La maledizione della prima luna - Pirates of the Caribbean::Italy (DVD title)', u'Oi peirates tis Karaivikis: I katara tou mavrou margaritariou::Greece (transliterated ISO-LATIN-1 title)', u'Pir\xe1ti z Karibiku::Czech Republic (alternative title)', u'Pir\xe1ti z Karibiku::Slovakia', u'Pir\xe1ti z Karibiku - Proklet\xed Cern\xe9 perly::Czech Republic', u'Piraci z Karaib\xf3w: Klatwa Czarnej Perly::Poland', u'Piratas das Cara\xedbas - A Maldi\xe7\xe3o do P\xe9rola Negra::Portugal', u'Piratas del Caribe: La maldici\xf3n de la Perla Negra::Spain (imdb display title)', u'Piratas do Caribe: A Maldi\xe7\xe3o do P\xe9rola Negra::Brazil (imdb display title)', u'Pirates des Cara\xefbes - La mal\xe9diction de la Perle Noire::Canada (French title)', u'Pirates des Cara\xefbes - La mal\xe9diction du Black Pearl::France (imdb display title)', u'Pirates of the Caribbean: Den sorte forbandelse::Denmark (imdb display title)', u'Pirates of the Caribbean: Mustan helmen kirous::Finland', u'Pirates of the Caribbean: Svarta P\xe4rlans f\xf6rbannelse::Sweden (imdb display title)', u'Pirati dei Caraibi: La maledizione della prima luna::Italy (alternative title)', u'Pirati s Kariba: Prokletstvo Crnog bisera::Croatia (imdb display title)', u'Pirati s Karibov: prekletstvo \u010drnega bisera::Slovenia', u'Pirati sa Kariba - Prokletstvo Crnog bisera::Serbia (imdb display title)', u'Piratii din Caraibe: Blestemul Perlei Negre::Romania (imdb display title)', u"Shodeday Ha-Caribim: Klalat Ha-Pnina Ha-Sh'hora::Israel (Hebrew title)", u'Sj\xf3r\xe6ningjar \xe1 Kar\xedbahafi: B\xf6lvun sv\xf6rtu perlunnar::Iceland (imdb display title)']
# amazon reviews
# None
# art direction
# [<Person id:0384192[http] name:_Hill, Derek R._>, <Person id:0694358[http] name:_Powels, Michael_>, <Person id:0865042[http] name:_Tocci, James E._>, <Person id:0003555[http] name:_Woodruff, Donald B._>]
# assistant director
# [<Person id:0064663[http] name:_Beaupre, Steven F._>, <Person id:0278498[http] name:_Fiorelli, Gary Romolo_>, <Person id:0375512[http] name:_Hellmann, Susan J._>, <Person id:0376712[http] name:_Hendricks, Bruce_>, <Person id:0463406[http] name:_Kohn, Peter_>, <Person id:1021871[http] name:_Mantoux, Lisa_>, <Person id:0729633[http] name:_Rivetti, Darin_>, <Person id:0744849[http] name:_Roth, Frederic_>, <Person id:0773972[http] name:_Schneider, Paul_>, <Person id:0911368[http] name:_Ward, Andrew_>, <Person id:0936838[http] name:_Witt, Alexander_>]
# cast
# [<Person id:0000136[http] name:_Depp, Johnny_>, <Person id:0001691[http] name:_Rush, Geoffrey_>, <Person id:0089217[http] name:_Bloom, Orlando_>, <Person id:0461136[http] name:_Knightley, Keira_>, <Person id:0202603[http] name:_Davenport, Jack_>, <Person id:0000596[http] name:_Pryce, Jonathan_>, <Person id:0034305[http] name:_Arenberg, Lee_>, <Person id:0188871[http] name:_Crook, Mackenzie_>, <Person id:1400933[http] name:_O'Hare, Damian_>, <Person id:1099016[http] name:_New, Giles_>, <Person id:0055845[http] name:_Barnett, Angus_>, <Person id:0047549[http] name:_Bailie, David_>, <Person id:1400913[http] name:_Jr., Michael Berry_>, <Person id:0802280[http] name:_Jr., Isaac C. Singleton_>, <Person id:0573618[http] name:_McNally, Kevin_>, <Person id:0262125[http] name:_Etienne, Treva_>, <Person id:0757855[http] name:_Saldana, Zoe_>, <Person id:0801838[http] name:_Siner, Guy_>, <Person id:0552924[http] name:_Martin, Ralph P._>, <Person id:0628225[http] name:_Newman, Paula J._>, <Person id:0445284[http] name:_Keith, Paul_>, <Person id:0808057[http] name:_Smith, Dylan_>, <Person id:1096355[http] name:_Dryzek, Lucinda_>, <Person id:0212472[http] name:_de Woolfson, Luke_>, <Person id:0992126[http] name:_Tighe, Michael Sean_>, <Person id:0254862[http] name:_Rees, Jonny_>, <Person id:1400940[http] name:_Seavey, Dustin_>, <Person id:0552082[http] name:_Martin, Christian_>, <Person id:1147560[http] name:_Oyelumade, Israel_>, <Person id:0323845[http] name:_Goddard, Trevor_>, <Person id:0523629[http] name:_Lozano, Vince_>, <Person id:1088623[http] name:_Wilson, Ben_>, <Person id:0884356[http] name:_Valentino, Antonio_>, <Person id:1266413[http] name:_Maher, Lauren_>, <Person id:0101480[http] name:_Bowyer, Matthew_>, <Person id:1019725[http] name:_Cooper, Brye_>, <Person id:1839673[http] name:_Babcock, Mike_>, <Person id:1400923[http] name:_Finnegan, Owen_>, <Person id:1400928[http] name:_McIntyre, Ian_>, <Person id:0104376[http] name:_Branch, Vanessa_>, <Person id:1409636[http] name:_Roberts, Sam_>, <Person id:1400937[http] name:_Roberts, Ben_>, <Person id:0458514[http] name:_Klebba, Martin_>, <Person id:0145544[http] name:_Castro, Félix_>, <Person id:1310174[http] name:_Haberecht, Mike_>, <Person id:1310692[http] name:_McCollum, Rudy_>, <Person id:1296401[http] name:_Reyes, Gerard J._>, <Person id:1312205[http] name:_Shields, M. Scott_>, <Person id:1308961[http] name:_Sullivan, Christopher_>, <Person id:1308964[http] name:_Thomson, Craig_>, <Person id:1312246[http] name:_Toft, Fred_>, <Person id:1357198[http] name:_FitzGerald, D.P._>, <Person id:0310162[http] name:_Gauny, Jerry_>, <Person id:1335621[http] name:_Jr., Maxie Santillan_>, <Person id:1390274[http] name:_Lane, Michael Earl_>, <Person id:1283784[http] name:_McKinney, Tobias_>, <Person id:1310972[http] name:_Patykewich, David_>, <Person id:0774791[http] name:_Schooler, Tommy_>, <Person id:0860503[http] name:_Thompson, Michael A._>, <Person id:0931327[http] name:_Williams, Michael W._>, <Person id:1151823[http] name:_Zelaya, Jose_>, <Person id:1148570[http] name:_Egan, Finneus_>, <Person id:0480425[http] name:_LaDaga, Don_>, <Person id:0970985[http] name:_LeJon_>, <Person id:0135440[http] name:_Capp, Christopher S._>, <Person id:0003731[http] name:_Alosio, Gregory_>, <Person id:0127437[http] name:_Caballero, Jordi_>, <Person id:1278752[http] name:_Gagné, Paul_>, <Person id:0003784[http] name:_Grisaffi, Joe_>, <Person id:1054024[http] name:_McAuley, James_>]
# casting director
# [<Person id:1198012[http] name:_Alessi, Jennifer_>, <Person id:0006353[http] name:_Kress, Ronna_>]
# certificates
# [u'Argentina:Atp', u'Australia:M', u'Austria:10', u'Brazil:14', u'Canada:PG::(Alberta/British Columbia/Manitoba/Ontario)', u'Canada:14::(Nova Scotia) (original rating)', u'Canada:PG::(Nova Scotia) (re-rating on appeal)', u'Canada:G::(Quebec)', u'Chile:TE', u'Denmark:11', u'Finland:K-11/9', u'Finland:K-12/9::(2012 reform re-rating)', u'France:Tous publics', u'Germany:12', u'Greece:K-13', u'Hong Kong:IIA', u'Hungary:14', u'Iceland:10', u'Ireland:12', u'Italy:T', u'Malaysia:U', u'Netherlands:12', u'New Zealand:M', u'Norway:11', u'Peru:Apt', u'Philippines:PG-13', u'Portugal:M/12', u'Singapore:PG', u'Singapore:PG13::(re-rating)', u'South Korea:12', u'Spain:7', u'Sweden:11', u'Switzerland:12::(canton of Geneva)', u'Switzerland:12::(canton of Vaud)', u'Switzerland:12::(canton of the Grisons)', u'UK:12A::(original rating)', u'UK:12::(video rating)', u'USA:PG-13::(No. 40031)']
# cinematographer
# [<Person id:0003011[http] name:_Wolski, Dariusz_>]
# color info
# [u'Color']
# costume department
# [<Person id:0025392[http] name:_Best, Rochelle_>, <Person id:0095341[http] name:_Booher-Ciarimboli, Linda_>, <Person id:1061082[http] name:_Bronson, Toby_>, <Person id:2513020[http] name:_Casey, Dana_>, <Person id:2648185[http] name:_Cheng, Jay_>, <Person id:0165734[http] name:_Clayton, Lee_>, <Person id:0165734[http] name:_Clayton, Lee_>, <Person id:0189440[http] name:_Crouch, Ken_>, <Person id:0200349[http] name:_Dann, Liz_>, <Person id:0221761[http] name:_Dessert, Carolyn_>, <Person id:0226175[http] name:_Dietch, David_>, <Person id:0312347[http] name:_Gell, Steve_>, <Person id:0359997[http] name:_Hankins, Scott R._>, <Person id:0388033[http] name:_Hooey, Mathew_>, <Person id:0394918[http] name:_Horn, Stacy_>, <Person id:1287697[http] name:_Krueger, April_>, <Person id:0492332[http] name:_Law, Jane_>, <Person id:1176024[http] name:_Mancianti, Lorenzo_>, <Person id:0548121[http] name:_Marit, Marina_>, <Person id:0601014[http] name:_Moore-Telfer, Chandra_>, <Person id:1439633[http] name:_Murphy, Fran_>, <Person id:0629866[http] name:_Neufeld, Lesley_>, <Person id:0635957[http] name:_Norster, John_>, <Person id:1844852[http] name:_Palmer, Benjamin_>, <Person id:0729985[http] name:_Roach, Adam_>, <Person id:1460086[http] name:_Saul, Deanna M._>, <Person id:1138266[http] name:_Stone, Alexa M._>, <Person id:0865000[http] name:_Tobon, Gildardo_>, <Person id:4022188[http] name:_Walcott, Mark_>, <Person id:4022188[http] name:_Walcott, Mark_>, <Person id:0911823[http] name:_Ward, Ros_>, <Person id:4847579[http] name:_Warner, Darrell_>, <Person id:0937850[http] name:_Wolf, Lizz_>, <Person id:0939940[http] name:_Wood, Philippa_>, <Person id:0223203[http] name:_DeWitt, Dawn A._>, <Person id:1287578[http] name:_Joseff, Joan_>, <Person id:0915990[http] name:_Weaving, Joanna_>, <Person id:1430521[http] name:_Yoo, Tricia_>]
# costume designer
# [<Person id:0741606[http] name:_Rose, Penny_>]
# countries
# [u'USA']
# cover url
# https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1._SX95_SY140_.jpg
# creator
# None
# director
# [<Person id:0893659[http] name:_Verbinski, Gore_>]
# distributors
# [<Company id:0044374[http] name:_Walt Disney Company, The_>, <Company id:0044279[http] name:_Buena Vista Pictures_>, <Company id:0038978[http] name:_Bandur Film_>, <Company id:0148456[http] name:_Buena Vista International (Norway)_>, <Company id:0064622[http] name:_Buena Vista International_>, <Company id:0280125[http] name:_Buena Vista International_>, <Company id:0000779[http] name:_Buena Vista International_>, <Company id:0110125[http] name:_Buena Vista International_>, <Company id:0043796[http] name:_Buena Vista International_>, <Company id:0606142[http] name:_Buena Vista International_>, <Company id:0078276[http] name:_Buena Vista International_>, <Company id:0008734[http] name:_Buena Vista International_>, <Company id:0005389[http] name:_Buena Vista International_>, <Company id:0302554[http] name:_Buena Vista Pictures Distribution_>, <Company id:0040374[http] name:_Falcon_>, <Company id:0037052[http] name:_American Broadcasting Company (ABC)_>, <Company id:0234667[http] name:_BBC One_>, <Company id:0122774[http] name:_Buena Vista Home Entertainment_>, <Company id:0122774[http] name:_Buena Vista Home Entertainment_>, <Company id:0297430[http] name:_Buena Vista Home Entertainment_>, <Company id:0205811[http] name:_Buena Vista Home Entertainment_>, <Company id:0233565[http] name:_Buena Vista Home Entertainment_>, <Company id:0233565[http] name:_Buena Vista Home Entertainment_>, <Company id:0233565[http] name:_Buena Vista Home Entertainment_>, <Company id:0049546[http] name:_Buena Vista Home Entertainment_>, <Company id:0189769[http] name:_Buena Vista Home Video_>, <Company id:0044350[http] name:_Gativideo_>, <Company id:0044350[http] name:_Gativideo_>, <Company id:0129647[http] name:_Italia 1_>, <Company id:0118560[http] name:_SBS6_>, <Company id:0023299[http] name:_Veronica_>]
# editor
# [<Person id:0729701[http] name:_Rivkin, Stephen E._>, <Person id:0772831[http] name:_Schmidt, Arthur_>, <Person id:0939623[http] name:_Wood, Craig_>]
# faqs
# None
# full-size cover url
# https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3.jpg
# genres
# [u'Action', u'Adventure', u'Fantasy']
# guests
# None
# languages
# [u'English']
# make up
# [<Person id:0040025[http] name:_Astles, Martin_>, <Person id:0042063[http] name:_Aull, Jane_>, <Person id:0080388[http] name:_Bhavnani, Jacqueline_>, <Person id:1074053[http] name:_Boyle, Marc_>, <Person id:2046212[http] name:_Brennan, Kevin_>, <Person id:1498066[http] name:_Brown, Ron_>, <Person id:0117755[http] name:_Buacharern, Shutchai Tym_>, <Person id:0122178[http] name:_Burman, Barney_>, <Person id:0134148[http] name:_Cannom, Greg_>, <Person id:0134148[http] name:_Cannom, Greg_>, <Person id:0146217[http] name:_Catmull, Hazel_>, <Person id:0157494[http] name:_Childers, Catherine_>, <Person id:1237475[http] name:_Cyphers-Leake, Sheila_>, <Person id:1724995[http] name:_Davies, Natasha_>, <Person id:0216733[http] name:_DeLeon, David_>, <Person id:0222806[http] name:_Devlin, Leslie_>, <Person id:0225004[http] name:_Diaz, Ken_>, <Person id:2619159[http] name:_Donahue, John_>, <Person id:0994758[http] name:_Doyle, Claire_>, <Person id:0243495[http] name:_Dupuis, David_>, <Person id:1024255[http] name:_Eckert, Cheryl_>, <Person id:0262956[http] name:_Evans, Kris_>, <Person id:0263326[http] name:_Evans-Miller, Selena_>, <Person id:0263326[http] name:_Evans-Miller, Selena_>, <Person id:0281780[http] name:_Fleming, Romy_>, <Person id:1326905[http] name:_Franson, Nathan_>, <Person id:0296683[http] name:_Fruman, Shana_>, <Person id:0296764[http] name:_Fry, Kelcey_>, <Person id:0298193[http] name:_Fuller, Charmaine_>, <Person id:0299859[http] name:_G, Toni_>, <Person id:1309978[http] name:_Gallaher, Chris_>, <Person id:0302856[http] name:_Galli, Jane_>, <Person id:1000928[http] name:_Glassman, Rick_>, <Person id:2638908[http] name:_Grassi, Kenneth E._>, <Person id:1424050[http] name:_Hardy, Claudia_>, <Person id:0363355[http] name:_Harlow, Joel_>, <Person id:2264037[http] name:_Harlow, Pilar_>, <Person id:0370548[http] name:_Hay, Zoe_>, <Person id:2060838[http] name:_Henderson, Camille_>, <Person id:0403411[http] name:_Hurley, Ann-Maree_>, <Person id:1219719[http] name:_Jarvis, Tim_>, <Person id:2564038[http] name:_Kelly-Russo, Sharon_>, <Person id:1424051[http] name:_Kim, John_>, <Person id:0453602[http] name:_Kim, Mary_>, <Person id:0470997[http] name:_Kretschmer, Bob_>, <Person id:0485984[http] name:_Langan, Marese_>, <Person id:0486286[http] name:_Langer, Cammy R._>, <Person id:0513155[http] name:_Linsky, Felicia_>, <Person id:0522420[http] name:_Love, Sarah_>, <Person id:0532078[http] name:_Mace, Lucia_>, <Person id:0574709[http] name:_McVey, Sharon_>, <Person id:2563877[http] name:_Meck, Brian_>, <Person id:2394339[http] name:_Mercenier, Verena_>, <Person id:0591143[http] name:_Miner, Anthony_>, <Person id:0604676[http] name:_Morgan, Geneva Nash_>, <Person id:0608755[http] name:_Mosko, Gilbert A._>, <Person id:0624763[http] name:_Neill, Ve_>, <Person id:0625247[http] name:_Nelson, Christopher Allen_>, <Person id:0633835[http] name:_Noe, Douglas_>, <Person id:0635665[http] name:_Normand, Josée_>, <Person id:1018624[http] name:_O'Brien, Michael_>, <Person id:2388517[http] name:_Parr, James_>, <Person id:0664638[http] name:_Paskowitz, Nina_>, <Person id:0665481[http] name:_Patterson, Cristina_>, <Person id:0666625[http] name:_Patton, Scott_>, <Person id:0668404[http] name:_Payne, Michele_>, <Person id:0997729[http] name:_Perez, Yvette_>, <Person id:1424054[http] name:_Peterson, Michael_>, <Person id:0683732[http] name:_Pimentel, Art_>, <Person id:0688036[http] name:_Podnar, Joe_>, <Person id:0998593[http] name:_Price, Paula_>, <Person id:0706053[http] name:_Rae, Nikita_>, <Person id:0715927[http] name:_Rees, Katherine_>, <Person id:3075572[http] name:_Ritter, William_>, <Person id:0746457[http] name:_Rowden, Sandi_>, <Person id:0665625[http] name:_Rutherford, Deborah_>, <Person id:0751961[http] name:_Rutherford, Don_>, <Person id:0760407[http] name:_Samuel, Martin_>, <Person id:0760407[http] name:_Samuel, Martin_>, <Person id:0762149[http] name:_Sandoval, Maria_>, <Person id:1974357[http] name:_Schafer, Verina_>, <Person id:013900 ...
# merchandising links
# None
# misc links
# None
# miscellaneous companies
# [<Company id:0235245[http] name:_Absolute Rentals_>, <Company id:0137663[http] name:_Air Lyndhurst Studios_>, <Company id:0065161[http] name:_Asylum VFX_>, <Company id:0086014[http] name:_Avon Studio Transport_>, <Company id:0300363[http] name:_BT Industrial Supply_>, <Company id:0184542[http] name:_Bender ET_>, <Company id:0030240[http] name:_Birds & Animals Unlimited_>, <Company id:0067355[http] name:_Boone's Animals for Hollywood_>, <Company id:0009272[http] name:_Buena Vista Negative Cutting_>, <Company id:0060491[http] name:_Buena Vista Sound_>, <Company id:0008022[http] name:_Chapman/Leonard Studio Equipment_>, <Company id:0085849[http] name:_Cinevideo Tech_>, <Company id:0105378[http] name:_Cosprop_>, <Company id:0067412[http] name:_Custom Film Effects_>, <Company id:0296111[http] name:_Direct Tools & Fasteners_>, <Company id:0244588[http] name:_Filmtools_>, <Company id:0431057[http] name:_Funn_>, <Company id:0170029[http] name:_House of Moves Motion Capture Studios_>, <Company id:0046487[http] name:_J.L. Fisher_>, <Company id:0046487[http] name:_J.L. Fisher_>, <Company id:0016836[http] name:_Media Ventures_>, <Company id:0016836[http] name:_Media Ventures_>, <Company id:0204953[http] name:_Movie Movers_>, <Company id:0204953[http] name:_Movie Movers_>, <Company id:0003378[http] name:_Newman Scoring Stage, Twentieth Century Fox Studios, The_>, <Company id:0002792[http] name:_Panavision Remote Systems_>, <Company id:0041930[http] name:_Panavision_>, <Company id:0014704[http] name:_Pivotal Post_>, <Company id:0540296[http] name:_Pro-Cam Rentals_>, <Company id:0090951[http] name:_Scarlet Letters_>, <Company id:0030430[http] name:_Sessions Payroll Management_>, <Company id:0072003[http] name:_Skywalker Sound_>, <Company id:0279864[http] name:_Studios_>, <Company id:0131611[http] name:_THX Ltd._>, <Company id:0026777[http] name:_TM Equipment Rentals_>, <Company id:0065861[http] name:_Technicolor_>, <Company id:0044421[http] name:_Technique_>, <Company id:0044421[http] name:_Technique_>, <Company id:0044153[http] name:_Todd-AO Studios_>, <Company id:0494282[http] name:_Truck Brokers_>, <Company id:0057888[http] name:_Walt Disney Music Library, The_>, <Company id:0135174[http] name:_Walt Disney Records_>]
# miscellaneous crew
# [<Person id:2188457[http] name:_Andersen, Courtney J._>, <Person id:0026428[http] name:_Anderson, Bob_>, <Person id:1070921[http] name:_Anderson, Heather_>, <Person id:2500849[http] name:_Anderson, Lea_>, <Person id:1453581[http] name:_Baker, Louise_>, <Person id:1198917[http] name:_Batty, Christopher_>, <Person id:2242454[http] name:_Beckwith, Joe_>, <Person id:1590038[http] name:_Belaro-Rodriguez, Anna_>, <Person id:0075373[http] name:_Berkery, Barbara_>, <Person id:1289661[http] name:_Betz, Michael_>, <Person id:1171657[http] name:_Blampied, Justin_>, <Person id:0091540[http] name:_Bogard, Jason_>, <Person id:1932526[http] name:_Bokides, Rich_>, <Person id:1298324[http] name:_Bonnin, John_>, <Person id:0105915[http] name:_Brauner, Ursula_>, <Person id:2005009[http] name:_Bronson, Juan_>, <Person id:0112152[http] name:_Brooks, Maxine_>, <Person id:0115414[http] name:_Bruce, Andrea_>, <Person id:0127709[http] name:_Cabral, Anne_>, <Person id:0131861[http] name:_Camins, Dan_>, <Person id:1192578[http] name:_Campbell, John K._>, <Person id:4993377[http] name:_Canavan, Jimmy_>, <Person id:0166683[http] name:_Clifford, Sarah_>, <Person id:0176862[http] name:_Coogan, Leslie_>, <Person id:1039744[http] name:_Cuesta, Dax A._>, <Person id:0203840[http] name:_Davies, Mark_>, <Person id:0204067[http] name:_Davila, Ted M._>, <Person id:0002324[http] name:_Dawson, Robert_>, <Person id:0218259[http] name:_Dembrowski, Christi_>, <Person id:1287039[http] name:_DeTample, Kelly_>, <Person id:2175920[http] name:_Donno, Kathy_>, <Person id:0262419[http] name:_Eutsey, Stan_>, <Person id:1287213[http] name:_Finnigan, Brendan_>, <Person id:2567896[http] name:_Fitzpatrick, Kevin_>, <Person id:1355093[http] name:_Garritano, George_>, <Person id:0313593[http] name:_George, Robert_>, <Person id:0325273[http] name:_Goldberg, Michael_>, <Person id:0351286[http] name:_Gomez, Zoila_>, <Person id:1490693[http] name:_Gorski, Ro_>, <Person id:0004562[http] name:_Greenwood, Peter_>, <Person id:2229882[http] name:_Gregus, Michal_>, <Person id:1299662[http] name:_Greitzer, Lindsay_>, <Person id:0349178[http] name:_Gutentag, Gabriela_>, <Person id:3174809[http] name:_Hambleton, Charles_>, <Person id:0362103[http] name:_Harden, Mark_>, <Person id:1334189[http] name:_Harmatz, Stephanie L._>, <Person id:1334189[http] name:_Harmatz, Stephanie L._>, <Person id:1118338[http] name:_Havener, Marc W._>, <Person id:2759156[http] name:_Hayman, Deon_>, <Person id:1365573[http] name:_Heath, Zack_>, <Person id:0382949[http] name:_Hicks, Rick_>, <Person id:0390627[http] name:_Holland, Buck_>, <Person id:0409129[http] name:_Inman, Jason_>, <Person id:0412413[http] name:_Ivie, Mark_>, <Person id:0412413[http] name:_Ivie, Mark_>, <Person id:1755006[http] name:_Jacyszyn, Mark_>, <Person id:0416474[http] name:_James, Emmett_>, <Person id:0418013[http] name:_Jansen, JoAnn Fregalette_>, <Person id:2618732[http] name:_Jimenez, Yvonne_>, <Person id:0131960[http] name:_Kamp, Alec_>, <Person id:1221036[http] name:_Kavner, Ryan_>, <Person id:0452999[http] name:_Kiley, Jim_>, <Person id:0456593[http] name:_Kirkeby, Samantha C._>, <Person id:3044224[http] name:_Kruger, Kristin_>, <Person id:1136952[http] name:_Laurel, Ernst W._>, <Person id:1184240[http] name:_Lee, Rich_>, <Person id:0500177[http] name:_Leigh, Barrett J._>, <Person id:0513513[http] name:_Lipman, Jim_>, <Person id:1079863[http] name:_Lister, Ralph_>, <Person id:1259466[http] name:_Lombardo, Matt_>, <Person id:0523323[http] name:_Lowry, Harvey_>, <Person id:0523714[http] name:_Lu, Harry_>, <Person id:0540409[http] name:_Malone, Daniel F._>, <Person id:2398402[http] name:_Manzoni, Kenneth_>, <Person id:0545254[http] name:_Marcena, Rick_>, <Person id:0563172[http] name:_Mazaraki, Robert_>, <Person id:0566019[http] name:_McClure, Matthew_>, <Person id:1520186[http] name:_McGinn, Brian_>, <Person id:1031263[http] name:_Medeiros, Justin_>, <Person id:3557352[http] name:_Medic, Dusan_>, <Person id:0588661[http] name:_Miller, Jon_>, ...
# non-original music
# None
# number of episodes
# None
# number of seasons
# None
# original music
# [<Person id:0046004[http] name:_Badelt, Klaus_>]
# parents guide
# None
# photo sites
# None
# plot
# [u"This swash-buckling tale follows the quest of Captain Jack Sparrow, a savvy pirate, and Will Turner, a resourceful blacksmith, as they search for Elizabeth Swann. Elizabeth, the daughter of the governor and the love of Will's life, has been kidnapped by the feared Captain Barbossa. Little do they know, but the fierce and clever Barbossa has been cursed. He, along with his large crew, are under an ancient curse, doomed for eternity to neither live, nor die. That is, unless a blood sacrifice is made.", u"When Captain Barbossa sends his pirate crew to kidnap Elizabeth Swan and the last remaining piece of Aztec gold. A blacksmith called Will Turner joins a recently captured pirate named Jack Sparrow and goes off searching for Elizabeth. It's isn't until they all meet up, that they discover the real terrifying truth behind the Aztec gold, and why they need Will Turner and not Elizabeth Swan.", u'William Turner, a resourceful young blacksmith, teams up with the eccentric pirate "Captain" Jack Sparrow to save his love, the Governor\'s daughter, Elizabeth Swann, who has been mistakenly captured by the clever and treacherous Barbossa, a former ally of Jack, to make a blood sacrifice so as to end the curse that has been casted upon him and his crew. Will and Jack steal a ship from the Royal Navy and arrive at Tortuga, a pirate port. There Jack meets his friend Joshamee Gibbs and with a buccaneer and "able bodied" crew, set sail to save Elizabeth and take back the Black Pearl. Meanwhile, Barbossa discovers that not Elizabeth\'s but someone else\'s blood was required for the sacrifice. Whose blood is it?', u"Pirates of the Caribbean is a sweeping action-adventure story set in an era when villainous pirates scavenged the Caribbean seas. This roller coaster tale teams a young man, Will Turner, with an unlikely ally in rogue pirate Jack Sparrow. Together, they must battle a band of the world's most treacherous pirates, led by the cursed Captain Barbossa, in order to save Elizabeth, the love of Will's life, as well as recover the lost treasure that Jack seeks. Against improbable odds, they race towards a climactic confrontation on the mysterious Isla de Muerta. Clashing their swords in fierce mortal combat, Will and Jack attempt to recapture The Black Pearl ship, save the British navy, and relinquish a fortune in forbidden treasure thereby lifting the curse of the Pirates of the Caribbean.", u"After Elizabeth Swann is kidnapped by the evil Captain Barbossa and his crew, the blacksmith Will Turner and the pirate Jack Sparrow, who used to be captain of Barbossa's ship, team up to rescue Ms. Swann. But they soon discover that the pirates have their own secret, sinister purpose with Ms. Swann, and that there's much more going on that a simple kidnapping.", u'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.']
# producer
# [<Person id:0000988[http] name:_Bruckheimer, Jerry_>, <Person id:0213226[http] name:_Deason, Paul_>, <Person id:0376712[http] name:_Hendricks, Bruce_>, <Person id:0648288[http] name:_Oman, Chad_>, <Person id:0762389[http] name:_Sandston, Pat_>, <Person id:0826679[http] name:_Stenson, Mike_>]
# production companies
# [<Company id:0008970[http] name:_Walt Disney Pictures_>, <Company id:0026281[http] name:_Jerry Bruckheimer Films_>]
# production manager
# [<Person id:0213226[http] name:_Deason, Paul_>, <Person id:1083627[http] name:_Goldman, Tami_>, <Person id:0371669[http] name:_Hayslip, Thomas_>, <Person id:0376712[http] name:_Hendricks, Bruce_>, <Person id:0581241[http] name:_Merrifield, Douglas C._>]
# rating
# 8.0
# runtimes
# [u'143']
# set decoration
# [<Person id:0224878[http] name:_Dias, Larry_>, <Person id:7303391[http] name:_Bertocco, Cristian_>]
# sound clips
# None
# sound crew
# [<Person id:0015084[http] name:_Akander, Ulrika_>, <Person id:0027211[http] name:_Anderson, Mike_>, <Person id:0036407[http] name:_Arnold, David A._>, <Person id:0039305[http] name:_Ashwill, James_>, <Person id:1538311[http] name:_Biggers, Jeffrey_>, <Person id:0102110[http] name:_Boyes, Christopher_>, <Person id:0102110[http] name:_Boyes, Christopher_>, <Person id:0102110[http] name:_Boyes, Christopher_>, <Person id:0132372[http] name:_Campbell, David E._>, <Person id:1183783[http] name:_Cooper, Colin_>, <Person id:0190961[http] name:_Cucci, John T._>, <Person id:0194966[http] name:_D'Alessandro, Gloria_>, <Person id:1584690[http] name:_Dahanne, Colette D._>, <Person id:0199397[http] name:_Danelski, Christine_>, <Person id:0203511[http] name:_Davidson, Valerie_>, <Person id:4279933[http] name:_Dias, André_>, <Person id:0233782[http] name:_Dorman, Teri E._>, <Person id:0279017[http] name:_Fischer, Ken_>, <Person id:0282484[http] name:_Flockoi, Erik_>, <Person id:1289922[http] name:_Foley, Nick_>, <Person id:0297156[http] name:_Fucci, Marva_>, <Person id:0302667[http] name:_Gallavan, Jessica_>, <Person id:0322367[http] name:_Gleaves, Peter_>, <Person id:0365754[http] name:_Harrison, Matthew_>, <Person id:0391796[http] name:_Holmes, David_>, <Person id:1479400[http] name:_Hopkins, Larry_>, <Person id:0463296[http] name:_Kohler, Steve_>, <Person id:1910326[http] name:_Lambourn, Matthew_>, <Person id:0505878[http] name:_Levine, Lisa J._>, <Person id:0510160[http] name:_Likowski, James_>, <Person id:0529345[http] name:_Lytle, Melissa_>, <Person id:0553178[http] name:_Martin, Victoria_>, <Person id:1072340[http] name:_Mion, Jo_>, <Person id:2068275[http] name:_Moreno, Magic A._>, <Person id:0631004[http] name:_Nielsen, Tim_>, <Person id:0640006[http] name:_O'Connell, Dan_>, <Person id:0650090[http] name:_Orloff, Lee_>, <Person id:0662188[http] name:_Parker, David_>, <Person id:0668448[http] name:_Payne, Thomas A._>, <Person id:0734730[http] name:_Rogers, Keith_>, <Person id:0760222[http] name:_Sampson, Victoria Rose_>, <Person id:0003718[http] name:_Scharf, Larry_>, <Person id:0777062[http] name:_Schwalbe, Solange S._>, <Person id:0798020[http] name:_Silk, Gregg_>, <Person id:0816792[http] name:_Spangenberg, Karen_>, <Person id:0824555[http] name:_Steele, Greg_>, <Person id:0841743[http] name:_Swanscott, Ted_>, <Person id:0852357[http] name:_Taylor, F. Scott_>, <Person id:0853529[http] name:_Teague, Addison_>, <Person id:0915036[http] name:_II, George Watters_>, <Person id:0925678[http] name:_Whitehead, Dave_>, <Person id:0938536[http] name:_Wollage, Nick_>, <Person id:0943561[http] name:_Wyatt, Keenan_>, <Person id:0236055[http] name:_Downie, Aren_>, <Person id:2629157[http] name:_Potter, Stephen W._>]
# special effects
# None
# special effects companies
# [<Company id:0007612[http] name:_Keith Vanderlaan's Captive Audience Productions_>, <Company id:0072491[http] name:_Industrial Light & Magic (ILM)_>, <Company id:0016567[http] name:_Boy Wonder Visual Effects_>, <Company id:0063107[http] name:_CIS Hollywood_>, <Company id:0004771[http] name:_Digiscope_>, <Company id:0087090[http] name:_Gray Matter FX_>, <Company id:0078782[http] name:_Method Studios_>, <Company id:0001256[http] name:_Pacific Title_>, <Company id:0064820[http] name:_Pixel Liberation Front_>, <Company id:0126846[http] name:_Gentle Giant Studios_>, <Company id:0019087[http] name:_Makeup Effects Group Studio_>, <Company id:0107949[http] name:_Professional VisionCare Associates_>]
# stunt performer
# [<Person id:0004669[http] name:_Albert, Laura_>, <Person id:0025739[http] name:_Anaya, Joey_>, <Person id:0029722[http] name:_Angelotti, Tony_>, <Person id:0029722[http] name:_Angelotti, Tony_>, <Person id:0031493[http] name:_Antonucci, Christopher 'Critter'_>, <Person id:0034009[http] name:_Arden, Noby_>, <Person id:0036364[http] name:_Arnold, Bob_>, <Person id:0043013[http] name:_Avery, Brian_>, <Person id:1290743[http] name:_Baker, Matt_>, <Person id:0057460[http] name:_Barringer, Daniel W._>, <Person id:0085949[http] name:_Blackwell, Richard L._>, <Person id:0100590[http] name:_Bovee, Brad_>, <Person id:0101500[http] name:_Box, Joey_>, <Person id:0123592[http] name:_Burton, Hal_>, <Person id:0132625[http] name:_Campbell, Keith_>, <Person id:0149496[http] name:_Chadwick, Mark_>, <Person id:1058072[http] name:_Chansky, Alex_>, <Person id:1002633[http] name:_Chon, Arnold_>, <Person id:0171018[http] name:_Coleman, Doug_>, <Person id:0171903[http] name:_Collier, Eugene_>, <Person id:1132085[http] name:_Connolly, Tim_>, <Person id:0183618[http] name:_Counts, Brycen_>, <Person id:1247999[http] name:_Cullen, Clay_>, <Person id:0191622[http] name:_Culotta, Phil_>, <Person id:0206905[http] name:_De Alessandro, Mark_>, <Person id:0212605[http] name:_Sr., Vince Deadrick_>, <Person id:0228882[http] name:_Dixon, John_>, <Person id:0232116[http] name:_Donaldson, J. Mark_>, <Person id:0241535[http] name:_Dumenigo, Jayson_>, <Person id:0243345[http] name:_DuPont, Thomas_>, <Person id:0243345[http] name:_DuPont, Thomas_>, <Person id:0252926[http] name:_Elam, Kofi_>, <Person id:0253639[http] name:_Eliopoulos, Paul_>, <Person id:0255470[http] name:_Elmore, Bob_>, <Person id:0263445[http] name:_Evenson, Dana Dru_>, <Person id:0267258[http] name:_Farwell, Dane_>, <Person id:0279510[http] name:_Fisher, George_>, <Person id:4900894[http] name:_Foxx, Sebastian_>, <Person id:5794588[http] name:_Fry, Gary_>, <Person id:0316912[http] name:_Gibson, Dale_>, <Person id:0318739[http] name:_Gill, Tanner_>, <Person id:0333689[http] name:_Graf, Allan_>, <Person id:1129976[http] name:_Grimes, Dean_>, <Person id:0356013[http] name:_Hall, Randy_>, <Person id:0362670[http] name:_Hardy, Jim_>, <Person id:0368819[http] name:_Hatem, Rosine 'Ace'_>, <Person id:3553063[http] name:_Hay, John_>, <Person id:0379463[http] name:_Hermz, Nick_>, <Person id:0392470[http] name:_Holt, Larry_>, <Person id:0397917[http] name:_Howell, Norman_>, <Person id:0398388[http] name:_Hoyle, Lisa_>, <Person id:0412413[http] name:_Ivie, Mark_>, <Person id:0425113[http] name:_Johnson, Gainer_>, <Person id:1044413[http] name:_Keller, Oliver_>, <Person id:0455374[http] name:_King, Wayne_>, <Person id:0477465[http] name:_Kypri, Theo_>, <Person id:0503427[http] name:_Leps, Christopher_>, <Person id:0521511[http] name:_Lott, Kurt D._>, <Person id:0560006[http] name:_Matthews, Eddie_>, <Person id:0575216[http] name:_Mears, Derek_>, <Person id:0604426[http] name:_Morga, Tom_>, <Person id:0610267[http] name:_Mower, Caryn_>, <Person id:1241898[http] name:_Munsterman, Sonja_>, <Person id:1171021[http] name:_Murray, Marty_>, <Person id:0635800[http] name:_Norris, Eric_>, <Person id:0639586[http] name:_O'Brien, Hugh Aodh_>, <Person id:0642110[http] name:_O'Neill, Casey_>, <Person id:0650131[http] name:_Orlov, Vladimir_>, <Person id:0650658[http] name:_Orrison, Brad_>, <Person id:0654211[http] name:_Owen, Michael_>, <Person id:0682334[http] name:_Pierce, Denney_>, <Person id:0721942[http] name:_Reynolds, Samuel_>, <Person id:0733421[http] name:_Robotham, John_>, <Person id:0718264[http] name:_Rodriguez, Jason_>, <Person id:0708015[http] name:_Romano, J.P._>, <Person id:0740951[http] name:_Jr., Thomas Rosales_>, <Person id:0740962[http] name:_Rosales, Gilbert_>, <Person id:0743539[http] name:_Ross, John_>, <Person id:0741396[http] name:_Ruge, George Marshall_>, <Person id:1190907[http] name:_Russo, Jason_>, <Person id:0787318[http] name:_Schaffer, Marc_>, <Person id:0773075[http] name:_Schmidt, Liane_>,  ...
# video clips
# None
# visual effects
# [<Person id:0009204[http] name:_Abrams, Lauren_>, <Person id:0027144[http] name:_Anderson, Mark_>, <Person id:1144796[http] name:_Anielewicz, Will_>, <Person id:0035658[http] name:_Armstrong, Chris_>, <Person id:0039882[http] name:_Assmus, Carl_>, <Person id:0047128[http] name:_Bailey, Al_>, <Person id:0047185[http] name:_Bailey, Charles_>, <Person id:2325736[http] name:_Bailey, Peter_>, <Person id:1453581[http] name:_Baker, Louise_>, <Person id:1427987[http] name:_Balog, Michael_>, <Person id:1925741[http] name:_Barbier, Leigh_>, <Person id:1198917[http] name:_Batty, Christopher_>, <Person id:0002762[http] name:_Baumann, Travis_>, <Person id:0063458[http] name:_Beach, Dugan_>, <Person id:1278511[http] name:_Behrens, Joel_>, <Person id:0067480[http] name:_Bel, Linda_>, <Person id:0081636[http] name:_Bies, Don_>, <Person id:0081861[http] name:_Biggs, R. Christopher_>, <Person id:0082619[http] name:_Billups, Minky_>, <Person id:1193862[http] name:_Blackman, Duncan_>, <Person id:0091793[http] name:_Bogh, Stella_>, <Person id:0094878[http] name:_Bonnenfant, Scott_>, <Person id:0102284[http] name:_Boyle, Kim_>, <Person id:0102821[http] name:_Brackett, Jason_>, <Person id:1388604[http] name:_Brakensiek, Timothy_>, <Person id:0107438[http] name:_Brenneis, Marty_>, <Person id:0112059[http] name:_Brooks, Jill_>, <Person id:0113798[http] name:_Brown, Jason_>, <Person id:1584403[http] name:_Brummel, Dhyana_>, <Person id:1410164[http] name:_Bryant, David C._>, <Person id:0118392[http] name:_Buck, Mark_>, <Person id:1080828[http] name:_Bullock, David_>, <Person id:0123255[http] name:_Burrow, Cathy_>, <Person id:1538486[http] name:_Calanchini, Michaela_>, <Person id:1154485[http] name:_Camera-Smith, Scott_>, <Person id:0132470[http] name:_Campbell, Geoff_>, <Person id:0132873[http] name:_Campbell, Sue_>, <Person id:0141954[http] name:_Carter, Tami_>, <Person id:0142200[http] name:_Cartwright, Randy_>, <Person id:0144086[http] name:_Cassella, John_>, <Person id:1538592[http] name:_Cheney, Grace_>, <Person id:0158767[http] name:_Choe, Minhee_>, <Person id:0989044[http] name:_Christensen, Eric D._>, <Person id:0160860[http] name:_Chu, Marc_>, <Person id:0161458[http] name:_Churchill, Paul_>, <Person id:0162831[http] name:_Cisneros, Eduardo_>, <Person id:0166037[http] name:_Clemens, Michael_>, <Person id:0167122[http] name:_Clot, Robbie_>, <Person id:0168819[http] name:_Cofer, Grady_>, <Person id:0175391[http] name:_Connor, Brian_>, <Person id:0176250[http] name:_Conte, Michael_>, <Person id:0176280[http] name:_Content, Caitlin_>, <Person id:0185800[http] name:_Craig, Catherine_>, <Person id:1095971[http] name:_Creaser, Gregory_>, <Person id:1129767[http] name:_Croft, Lee_>, <Person id:0192445[http] name:_Cunningham, Sean C._>, <Person id:1193547[http] name:_Curran, Sean_>, <Person id:0192929[http] name:_Currey, Gail_>, <Person id:0196898[http] name:_Dahl, Bruce_>, <Person id:0203063[http] name:_David, Scott_>, <Person id:0203065[http] name:_David, Scott_>, <Person id:0204696[http] name:_Baker, Heather Davis_>, <Person id:1505849[http] name:_De Quattro, Vince_>, <Person id:0217457[http] name:_Dellarosa, Lou_>, <Person id:1647909[http] name:_Derlich, Karin_>, <Person id:0221992[http] name:_Deuber, David_>, <Person id:1873229[http] name:_Dhawal, Amit_>, <Person id:0232983[http] name:_Donovan, Giovanni_>, <Person id:0234724[http] name:_Doucette, Andrew_>, <Person id:0241997[http] name:_Duncan, John_>, <Person id:0242888[http] name:_Dunne, Nika_>, <Person id:0244694[http] name:_Dusseault, Yanick_>, <Person id:0244745[http] name:_Dutch, Travis_>, <Person id:0247270[http] name:_Earl, Russell_>, <Person id:0248963[http] name:_Edelist, Evan_>, <Person id:2647552[http] name:_Edwards, Matt_>, <Person id:0250316[http] name:_Edwards, Robert_>, <Person id:0973118[http] name:_Fan, Leigh Ann_>, <Person id:0270826[http] name:_Fejes, Tom_>, <Person id:0283919[http] name:_Fogg, David_>, <Person id:0286050[http] name:_Foreman, Jon_>, <Person id:0288242[http] name ...
# writer
# [<Person id:0254645[http] name:_Elliott, Ted_>, <Person id:0744429[http] name:_Rossio, Terry_>, <Person id:0064181[http] name:_Beattie, Stuart_>, <Person id:0938684[http] name:_Wolpert, Jay_>, <Person id:0254645[http] name:_Elliott, Ted_>, <Person id:0744429[http] name:_Rossio, Terry_>]

# %%
tmdb_filename = str(dir_data)+'\\drv_tmdb_movie_details.json'
tmdb_movies = pd.read_json(tmdb_filename)
tmdb_movies.head(1)
# Out:
#      adult                     backdrop_path belongs_to_collection   budget  \
# 100  False  /kzeR7BA0htJ7BeI6QEUX3PVp39s.jpg                  None  1350000
#
#               genres                                           homepage   id  \
# 100  [Comedy, Crime]  http://www.universalstudiosentertainment.com/l...  100
#
#        imdb_id original_language                       original_title  \
# 100  tt0120735                en  Lock, Stock and Two Smoking Barrels
#
#        ...     release_date  revenue runtime spoken_languages    status  \
# 100    ...       1998-03-05  3897569   105.0        [English]  Released
#
#                                  tagline                                title  \
# 100  A Disgrace to Criminals Everywhere.  Lock, Stock and Two Smoking Barrels
#
#      video vote_average vote_count
# 100  False          7.4       1401
#
# [1 rows x 25 columns]

# %%
# get IMDB movies that we already have data for TMDB
imdb_ids = tmdb_movies['imdb_id'].tolist()
tmdb_ids = tmdb_movies['id'].tolist()

imdb_ids = [ str(imdb_id.replace('tt','')) for imdb_id in imdb_ids]
imdb_ids = [ imdb_id for imdb_id in imdb_ids if imdb_id !='' and imdb_id is not None]

imdb_ids = list(set(imdb_ids))

# %%
tmdb_movies.head(1)
# Out:
#      adult                     backdrop_path belongs_to_collection   budget  \
# 100  False  /kzeR7BA0htJ7BeI6QEUX3PVp39s.jpg                  None  1350000
#
#               genres                                           homepage   id  \
# 100  [Comedy, Crime]  http://www.universalstudiosentertainment.com/l...  100
#
#        imdb_id original_language                       original_title  \
# 100  tt0120735                en  Lock, Stock and Two Smoking Barrels
#
#        ...     release_date  revenue runtime spoken_languages    status  \
# 100    ...       1998-03-05  3897569   105.0        [English]  Released
#
#                                  tagline                                title  \
# 100  A Disgrace to Criminals Everywhere.  Lock, Stock and Two Smoking Barrels
#
#      video vote_average vote_count
# 100  False          7.4       1401
#
# [1 rows x 25 columns]

# %%
# verify that we get the same movie as TMDB

imdb = IMDb()
imdb_movie = imdb.get_movie(imdb_id)
#access attributes of the movie by dictionary keys
imdb.update(imdb_movie)
imdb_movie['title']
# Out:
# u'Der freie Wille'

# %%
print(imdb_movie)
# Out:
# Der freie Wille

# %%
imdb_info_column = imdb_movie.keys_alias.values()
imdb_info_column = list(set(imdb_info_column))
if 'imdb_id' not in imdb_info_column:
    imdb_info_column.append('imdb_id')
imdb_info_column.sort()

movies = pd.DataFrame(columns=imdb_info_column)
invalid_imdb_ids = []

imdb_filename = str(dir_data)+'\\drv_imdb_movie_info.json'
imdb_filename_backup = str(dir_data)+'\\drv_imdb_movie_info_bkp.json'
imdb_invalid_id_filename = str(dir_data)+'\\drv_imdb_movie_invalid_id.json'
count = 0
# if we already have a movie data file, we can just continue appending it instead of starting from id 1 again.
if os.path.isfile(imdb_filename):
    movies = pd.read_json(imdb_filename)
    if len(movies['imdb_id'].tolist()) >0:
        movie_ids = movies['imdb_id'].tolist()
        imdb_ids = [x for x in imdb_ids if x not in movie_ids]
        imdb_info_column = movies.columns
    else:
        movies = pd.DataFrame(columns=imdb_info_column)

# we don't want to waste our effort to load invalid imdb_id
if os.path.isfile(imdb_invalid_id_filename):
    invalid_imdb_id_df = pd.read_json(imdb_invalid_id_filename)
    if len(invalid_imdb_id_df['invalid_imdb_id'].tolist()) >0:
        invalid_imdb_ids = invalid_imdb_id_df['invalid_imdb_id'].tolist()
        imdb_ids = [x for x in imdb_ids if x not in invalid_imdb_ids]
        
for i in imdb_ids:
    count += 1
    if (count % 500 == 0):
        movies.to_json(path_or_buf= imdb_filename)
        if (len(invalid_imdb_ids)>0):
            invalid_imdb_id_df = pd.DataFrame({'invalid_imdb_id': invalid_imdb_ids}) 
            invalid_imdb_id_df.to_json(path_or_buf= imdb_invalid_id_filename)
    #skip the non-existing movie ids
    #print(i)
    try:
        imdb_movie = imdb.get_movie(i)
        imdb.update(imdb_movie)
        if (len(imdb_movie.keys()) > 0) :       
            movie_details = []
            for c in imdb_info_column:
                if imdb_movie.has_key(c):
                    info_field = imdb_movie[c]
                    if info_field is not None:
                        if type(info_field) is list:                    
                            if isinstance(info_field[0], ib.Person.Person):
                                info_list = []
                                for item in info_field:
                                    info_list.append(item.getID())
                                movie_details.append(info_list)
                            elif isinstance(info_field[0], ib.Company.Company):
                                info_list = []
                                for item in info_field:
                                    info_list.append(item.getID())
                                movie_details.append(info_list)  
                            else:
                                movie_details.append(info_field)
                        else:
                            movie_details.append(info_field)
                    else:
                        if c == "imdb_id":
                            movie_details.append(i)
                        else:
                            movie_details.append(None)      

                else:
                        movie_details.append(None)
                
            movies.loc[len(movies.index)] = movie_details
        
            movies.head(5)
    except Exception:
        invalid_imdb_ids.append(i)
        continue
        
movies.to_json(path_or_buf= imdb_filename)
if (len(invalid_imdb_ids)>0):
    invalid_imdb_id_df = pd.DataFrame({'invalid_imdb_id': invalid_imdb_ids}) 
    invalid_imdb_id_df.to_json(path_or_buf= imdb_invalid_id_filename)
# Out:
# 2017-04-05 12:31:48,582 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0072996/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')), 'errmsg': '[Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 202, in retrieve_unicode
#     uopener = self.open(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 213, in open
#     return getattr(self, name)(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 350, in open_http
#     h.endheaders(data)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1038, in endheaders
#     self._send_output(message_body)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 882, in _send_output
#     self.send(msg)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 844, in send
#     self.connect()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 821, in connect
#     self.timeout, self.source_address)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\socket.py", line 575, in create_connection
#     raise err
# IOError: [Errno socket error] [Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# 2017-04-05 12:31:48,592 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0072996" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0072996/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')), 'errmsg': '[Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'}
# 2017-04-05 12:40:09,298 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0044926/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10054, 'An existing connection was forcibly closed by the remote host')), 'errmsg': '[Errno 10054] An existing connection was forcibly closed by the remote host'},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 202, in retrieve_unicode
#     uopener = self.open(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 213, in open
#     return getattr(self, name)(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 351, in open_http
#     errcode, errmsg, headers = h.getreply()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1196, in getreply
#     response = self._conn.getresponse()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1121, in getresponse
#     response.begin()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 438, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 394, in _read_status
#     line = self.fp.readline(_MAXLINE + 1)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\socket.py", line 480, in readline
#     data = self._sock.recv(self._rbufsize)
# IOError: [Errno socket error] [Errno 10054] An existing connection was forcibly closed by the remote host
# 2017-04-05 12:40:09,305 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0044926" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0044926/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10054, 'An existing connection was forcibly closed by the remote host')), 'errmsg': '[Errno 10054] An existing connection was forcibly closed by the remote host'}
# 2017-04-05 12:45:38,263 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0463373/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10054, 'An existing connection was forcibly closed by the remote host')), 'errmsg': '[Errno 10054] An existing connection was forcibly closed by the remote host'},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 202, in retrieve_unicode
#     uopener = self.open(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 213, in open
#     return getattr(self, name)(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 351, in open_http
#     errcode, errmsg, headers = h.getreply()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1196, in getreply
#     response = self._conn.getresponse()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1121, in getresponse
#     response.begin()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 438, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 394, in _read_status
#     line = self.fp.readline(_MAXLINE + 1)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\socket.py", line 480, in readline
#     data = self._sock.recv(self._rbufsize)
# IOError: [Errno socket error] [Errno 10054] An existing connection was forcibly closed by the remote host
# 2017-04-05 12:45:38,270 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py:777: caught an exception retrieving or parsing "main" info set for mopID "0463373" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 506, in get_movie_main
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'combined')
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0463373/combined', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10054, 'An existing connection was forcibly closed by the remote host')), 'errmsg': '[Errno 10054] An existing connection was forcibly closed by the remote host'}
# 2017-04-05 13:33:52,992 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\_exceptions.py:35: IMDbDataAccessError exception raised; args: ({'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0314444/plotsummary', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')), 'errmsg': '[Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'},); kwds: {}
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 202, in retrieve_unicode
#     uopener = self.open(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 213, in open
#     return getattr(self, name)(url)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\urllib.py", line 350, in open_http
#     h.endheaders(data)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 1038, in endheaders
#     self._send_output(message_body)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 882, in _send_output
#     self.send(msg)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 844, in send
#     self.connect()
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\httplib.py", line 821, in connect
#     self.timeout, self.source_address)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\socket.py", line 575, in create_connection
#     raise err
# IOError: [Errno socket error] [Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# 2017-04-05 13:33:53,000 CRITICAL [imdbpy] C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py:777: caught an exception retrieving or parsing "plot" info set for mopID "0314444" (accessSystem: http)
# Traceback (most recent call last):
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\__init__.py", line 772, in update
#     ret = method(mopID)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 514, in get_movie_plot
#     cont = self._retrieve(self.urls['movie_main'] % movieID + 'plotsummary')
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 453, in _retrieve
#     ret = self.urlOpener.retrieve_unicode(url, size=size)
#   File "C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\imdb\parser\http\__init__.py", line 236, in retrieve_unicode
#     'original exception': e})
# IMDbDataAccessError: {'exception type': 'IOError', 'url': 'http://akas.imdb.com/title/tt0314444/plotsummary', 'errcode': 'socket error', 'proxy': '', 'original exception': IOError('socket error', error(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')), 'errmsg': '[Errno 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-b09b816b9af9> in <module>()
#      71                         movie_details.append(None)
#      72
# ---> 73             movies.loc[len(movies.index)] = movie_details
#      74
#      75             movies.head(5)
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\core\indexing.pyc in __setitem__(self, key, value)
#     139             key = com._apply_if_callable(key, self.obj)
#     140         indexer = self._get_setitem_indexer(key)
# --> 141         self._setitem_with_indexer(indexer, value)
#     142
#     143     def _has_valid_type(self, k, axis):
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\core\indexing.pyc in _setitem_with_indexer(self, indexer, value)
#     383                                        name=indexer)
#     384
# --> 385                     self.obj._data = self.obj.append(value)._data
#     386                     self.obj._maybe_update_cacher(clear=True)
#     387                     return self.obj
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\core\frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4433             to_concat = [self, other]
#    4434         return concat(to_concat, ignore_index=ignore_index,
# -> 4435                       verify_integrity=verify_integrity)
#    4436
#    4437     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\tools\merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1450                        verify_integrity=verify_integrity,
#    1451                        copy=copy)
# -> 1452     return op.get_result()
#    1453
#    1454
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\tools\merge.pyc in get_result(self)
#    1648             new_data = concatenate_block_managers(
#    1649                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# -> 1650                 copy=self.copy)
#    1651             if not self.copy:
#    1652                 new_data._consolidate_inplace()
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\core\internals.pyc in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    4823     blocks = [make_block(
#    4824         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4825         placement=placement) for placement, join_units in concat_plan]
#    4826
#    4827     return BlockManager(blocks, axes)
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\core\internals.pyc in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2674         elif issubclass(vtype, np.complexfloating):
#    2675             klass = ComplexBlock
# -> 2676         elif is_categorical(values):
#    2677             klass = CategoricalBlock
#    2678         else:
#
# C:\Users\Chrystal\Anaconda2\envs\py27\lib\site-packages\pandas\types\common.pyc in is_categorical(array)
#      64 def is_categorical(array):
#      65     """ return if we are a categorical possibility """
# ---> 66     return isinstance(array, ABCCategorical) or is_categorical_dtype(array)
#      67
#      68
#
# KeyboardInterrupt:

# %%
#make a backup in case of corruption
copyfile(imdb_filename, imdb_filename_backup)

# %%
imdb_filename = str(dir_data)+'\\drv_imdb_movie_info.json'
imdb_movies = pd.read_json(imdb_filename)
imdb_movies.head(5)
# Out:
#       airing                                               akas  \
# 0        NaN  [Ultimate Avengers 2: Rise of the Panther::USA...
# 1        NaN  [Bajo la piel::Argentina (imdb display title),...
# 10       NaN  [Ultimate Avengers 2: Rise of the Panther::USA...
# 100      NaN  [One Wild Night::, USA (working title), Возмож...
# 1000     NaN  [Wicked City::Australia (imdb display title), ...
#
#       amazon reviews art direction                    assistant director  \
# 0                NaN          None                                  None
# 1                NaN          None  [0116502, 0348808, 0601635, 0931271]
# 10               NaN          None                                  None
# 100              NaN     [0055618]                    [0742835, 0815340]
# 1000             NaN     [0644470]                                  None
#
#                                                    cast  \
# 0     [1225431, 0217221, 0557219, 0941404, 0001882, ...
# 1     [0164809, 0891895, 0252961, 0862328, 0001026, ...
# 10    [1225431, 0217221, 0557219, 0941404, 0001882, ...
# 100   [0001844, 0000124, 0000551, 0612487, 0413698, ...
# 1000  [0946344, 0810987, 0589645, 0297847, 0448950, ...
#
#                  casting director  \
# 0                       [0800493]
# 1              [0058089, 0338418]
# 10                      [0800493]
# 100                     [0228938]
# 1000  [0532146, 0810987, 3108562]
#
#                                            certificates cinematographer  \
# 0     [Argentina:Atp::(DVD rating), Russia:12+, Russ...            None
# 1     [Argentina:18, Australia:MA15+, Netherlands:12...       [0312790]
# 10    [Argentina:Atp::(DVD rating), Russia:12+, Russ...            None
# 100   [Australia:PG, Germany:6, Iceland:L, South Kor...       [0005791]
# 1000  [Australia:R18+, Canada:18A::(Alberta/British ...       [0411060]
#
#      color info                        ...                         runtimes  \
# 0       [Color]                        ...                             [73]
# 1       [Color]                        ...                            [103]
# 10      [Color]                        ...                             [73]
# 100     [Color]                        ...                             [83]
# 1000    [Color]                        ...                             [82]
#
#      set decoration sound clips  \
# 0              None         NaN
# 1         [0048585]         NaN
# 10             None         NaN
# 100       [0460018]         NaN
# 1000           None         NaN
#
#                                              sound crew special effects  \
# 0     [0039305, 1409862, 1886186, 1423589, 0190961, ...             NaN
# 1     [2657542, 1434212, 1365757, 2850266, 0226886, ...             NaN
# 10    [0039305, 1409862, 1886186, 1423589, 0190961, ...             NaN
# 100       [0018482, 0081662, 0003263, 0463296, 0872150]             NaN
# 1000               [0262171, 1187913, 0593829, 0909603]             NaN
#
#      special effects companies              stunt performer video clips  \
# 0                         None                         None         NaN
# 1                         None           [2603844, 0915676]         NaN
# 10                        None                         None         NaN
# 100                       None  [0197780, 0258351, 2268592]         NaN
# 1000                      None                         None         NaN
#
#       visual effects                                             writer
# 0          [0777295]  [2092839, 1628806, 1080564, 1219736, 1080564, ...
# 1               None                                          [0000586]
# 10         [0777295]  [2092839, 1628806, 1080564, 1219736, 1080564, ...
# 100             None                                          [0000455]
# 1000            None               [0159109, 0452837, 0593377, 0810987]
#
# [5 rows x 50 columns]
